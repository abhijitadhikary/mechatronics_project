# %%
import torch
import numpy as np

# %%
model = torch.hub.load('pytorch/vision:v0.6.0', 'fcn_resnet101', pretrained=True).cuda()
model.classifier[4] = torch.nn.Conv2d(in_channels=512, out_channels=16, kernel_size=1, stride=1).cuda()
model.aux_classifier[4] = torch.nn.Conv2d(in_channels=256, out_channels=16, kernel_size=1, stride=1).cuda()
# Out:
# Using cache found in C:\Users\abhi/.cache\torch\hub\pytorch_vision_v0.6.0

# %%
dummy_tensor = torch.randn((10, 3, 224, 224), dtype=torch.float32).cuda()
dummy_tensor.shape
# Out:
# torch.Size([10, 3, 112, 112])

# %%
out= model(dummy_tensor)

# %%
out['out'][0].shape
# Out:
# torch.Size([16, 112, 112])

# %%
model.backbone.conv1 = torch.nn.Conv2d(in_channels=19, out_channels=64, kernel_size=6, stride=2, padding=3, bias=False)

# %%
model
# Out:
# FCN(
#   (backbone): IntermediateLayerGetter(
#     (conv1): Conv2d(19, 64, kernel_size=(6, 6), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
import torch
torch.__version__
# Out:
# '1.6.0'

# %%
out = model(dummy_tensor)

# %%
import torchvision

# %%
model = torchvision.models.segmentation.deeplabv3_resnet101(pretrained=False, progress=True, num_classes=16, aux_loss=None)

# %%
model.backbone
# Out:
# IntermediateLayerGetter(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
# ...

# %%
def get_max_value_heatmap(heatmap_stack):
    # heatmap_stack.shape = batch_size x num_keypoints x height x width
    batch_size = heatmap_stack.shape[0]
    num_keypoints = heatmap_stack.shape[1]

    keypoints_batch = torch.zeros((batch_size, num_keypoints * 2), dtype=torch.float32)

    for batch_index in range(batch_size):
        filter_index = 0
        for keypoint_index in range(0, num_keypoints, 2):
            row, col = torch.where(heatmap_stack[batch_index, filter_index] == torch.max(heatmap_stack[batch_index, filter_index]))
            if col.size()[0] > 0 or row.size()[0] > 0:
                row = row[-1]
                col = col[-1]
            keypoints_batch[batch_index, keypoint_index] = col
            keypoints_batch[batch_index, keypoint_index + 1] = row
            filter_index += 1

    return keypoints_batch

dummy_tensor =
